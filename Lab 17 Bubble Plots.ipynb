# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Bubble Plots**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on visualizing data.
#
# The dataset will be directly loaded into pandas for analysis and visualization.
#
# You will use various visualization techniques to explore the data and uncover key trends.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two data features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# #### Setup: Working with the Database
# **Install and import the needed libraries**

# %%
# !pip install pandas 
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows of the data to understand its structure
df.head()
# Out:
# --2024-12-28 02:59:23--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104, 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  35.5MB/s    in 4.3s
#
# 2024-12-28 02:59:27 (35.6 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %%
df = pd.read_csv("survey-data.csv")

# Display the first few rows of the data to understand its structure
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
df['JobSat'].unique()
df['LanguageHaveWorkedWith'].unique()
# Group by 'Country' and 'LanguageAdmired' and count the occurrences
df_split = df.assign(LanguageAdmired=df['LanguageAdmired'].str.split(';')).explode('LanguageAdmired')

# Group by 'Country' and 'LanguageAdmired' and count occurrences
country_tech = df_split.groupby(['Country', 'LanguageAdmired']).size().reset_index(name='Count')

# Get the top 10 most frequent countries
top_countries = df['Country'].value_counts().head(10).index

# Filter the grouped data to include only rows for the top 10 countries
country_tech_top = country_tech[country_tech['Country'].isin(top_countries)]
country_tech
# Out:
#           Country          LanguageAdmired  Count
# 0     Afghanistan                      Ada      1
# 1     Afghanistan                     Apex      1
# 2     Afghanistan                 Assembly      1
# 3     Afghanistan  Bash/Shell (all shells)      2
# 4     Afghanistan                        C      2
# ...           ...                      ...    ...
# 3152     Zimbabwe                      PHP      2
# 3153     Zimbabwe               PowerShell      3
# 3154     Zimbabwe                   Python      7
# 3155     Zimbabwe                      SQL      6
# 3156     Zimbabwe               TypeScript      4
#
# [3157 rows x 3 columns]

# %%
  # Time mapping
time_categories = {
        'Less than 15 minutes a day': 1,
        '15-30 minutes a day': 2,
        '30-60 minutes a day': 3,
        '60-120 minutes a day': 4,
        'Over 120 minutes a day': 5
    }

age_mapping = {
        'Under 18 years old': 17,
        '18-24 years old': 21,
        '25-34 years old': 29.5,
        '35-44 years old': 39.5,
        '45-54 years old': 49.5,
        '55-64 years old': 59.5,
        '65 years or older': 70,
        'Prefer not to say': None
    }
    
    # Create new column with mapped values
df['Age_Numeric'] = df['Age'].map(age_mapping)

Q1 = df['CompTotal'].quantile(0.25)
Q3 = df['CompTotal'].quantile(0.75)
IQR = Q3 - Q1
    
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
    
    # Create clean dataset
#clean_df = df[(df['CompTotal'] >= lower_bound) & (df['CompTotal'] <= upper_bound)].copy()
# Find the rows that don't meet the condition
mask = ~((df['CompTotal'] >= lower_bound) & (df['CompTotal'] <= upper_bound))
# Drop rows that don't meet the condition in place
df = df.reset_index(drop=True) 
df.drop(df[mask].index, inplace=True)
    
# Convert time data
df['TimeSearching_Num'] = df['TimeSearching'].map(time_categories)
df['TimeAnswering_Num'] = df['TimeAnswering'].map(time_categories)
df['Frustration_Count'] = df['Frustration'].str.count(';') + 1
df['JobSat'].fillna(df['JobSat'].median(), inplace=True)
df['JobSatPoints_6'].fillna(df['JobSatPoints_6'].median(), inplace=True)
df['SOPartFreq'].fillna(df['SOPartFreq'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_2031/3714533247.py:43: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['JobSat'].fillna(df['JobSat'].median(), inplace=True)
# /tmp/ipykernel_2031/3714533247.py:44: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
def create_comprehensive_bubble_analysis(df):
    """
    Creates comprehensive bubble plot visualizations
    """
    # 1. Age vs Participation Frequency
    plt.figure(figsize=(12, 8))
    sns.scatterplot(
        data=df,
        x='Age_Numeric',
        y='SOPartFreq',
        size='JobSat',
        sizes=(100, 1000),
        alpha=0.6
    )
    plt.title('Age vs Participation Frequency')
    plt.tight_layout()

    # 2. Compensation vs Job Satisfaction
    plt.figure(figsize=(12, 8))
    plt.scatter(
        df['ConvertedCompYearly'],
        df['JobSat'],
        s=df['Age_Numeric']*10,
        alpha=0.5
    )
    plt.title('Compensation vs Job Satisfaction (Size: Age)')
    plt.tight_layout()

    # 3. Technology Preferences by Age
    """plt.figure(figsize=(15, 8))
    df_clean = df.dropna(subset=['LanguageHaveWorkedWith'])

    tech_data = df_clean['LanguageHaveWorkedWith'].str.split(';').explode()
    #tech_counts = tech_data.value_counts().head(10)
    
    
    # Count the occurrences of each technology
    tech_counts = tech_data.value_counts()

    # Get the top 10 technologies (or you can adjust this number as needed)
    top_10_tech = tech_counts.head(10)

    # Filter out the rows in the original DataFrame for the top technologies
    df_filtered = df_clean[df_clean['LanguageHaveWorkedWith'].str.contains('|'.join(top_10_tech.index), na=False)]

    # Create a new column to represent which technology is most relevant to the individual
    #df_filtered['MostPreferredTech'] = df_filtered['LanguageHaveWorkedWith'].apply(
    #    lambda x: [tech for tech in x.split(';') if tech in top_10_tech.index][0] if isinstance(x, str) else None
    #)
    #df_filtered = df_filtered.dropna(subset=['MostPreferredTech'])


    # Create a scatter plot
    sns.scatterplot(
        x='MostPreferredTech',
        y='Age_Numeric',
        data=df_filtered,
        size=df_filtered['MostPreferredTech'].map(top_10_tech),
        sizes=(100, 2000),
        hue='MostPreferredTech',  # Optional: Color by technology for better visualization
        palette='Set1'  # Optional: Color palette for different technologies
    )
    plt.xticks(rotation=45)
    plt.title('Technology Preferences by Age')
    plt.tight_layout()
    




    

    # 4. Databases vs Job Satisfaction
    plt.figure(figsize=(15, 8))
    db_data = df['DatabaseWantToWorkWith'].str.split(';').explode()
    db_counts = db_data.value_counts().head(10)
    
    plt.scatter(
        db_counts.index,
        df['JobSat'],
        s=db_counts.values*10,
        alpha=0.6
    )
    plt.xticks(rotation=45)
    plt.title('Preferred Databases vs Job Satisfaction')
    plt.tight_layout()
    

    # 5. Compensation by Developer Role
    plt.figure(figsize=(15, 8))
    role_data = df['DevType'].str.split(';').explode()
    role_counts = role_data.value_counts().head(10)
    
    plt.scatter(
        role_counts.index,
        df['ConvertedCompYearly'],
        s=df['JobSat']*10,
        alpha=0.6
    )
    plt.xticks(rotation=45)
    plt.title('Compensation by Developer Role')
    plt.tight_layout()
    

    # 6. Collaboration Tools by Age
    plt.figure(figsize=(15, 8))
    tools_data = df['NEWCollabToolsHaveWorkedWith'].str.split(';').explode()
    tools_counts = tools_data.value_counts().head(10)
    
    sns.scatterplot(
        x=tools_counts.index,
        y=df['Age_Numeric'],
        size=tools_counts.values,
        sizes=(100, 2000)
    )
    plt.xticks(rotation=45)
    plt.title('Collaboration Tools by Age')
    plt.tight_layout()
    

    # 7. Web Frameworks vs Job Satisfaction
    plt.figure(figsize=(15, 8))
    framework_data = df['WebframeWantToWorkWith'].str.split(';').explode()
    framework_counts = framework_data.value_counts().head(10)
    
    plt.scatter(
        framework_counts.index,
        df['JobSat'],
        s=framework_counts.values*10,
        alpha=0.6
    )
    plt.xticks(rotation=45)
    plt.title('Web Frameworks vs Job Satisfaction')
    plt.tight_layout()
    """

    # 8. Technologies by Country
    plt.figure(figsize=(15, 8))
    df_split = df.assign(LanguageAdmired=df['LanguageAdmired'].str.split(';')).explode('LanguageAdmired')

    # Group by 'Country' and 'LanguageAdmired' and count occurrences
    country_tech = df_split.groupby(['Country', 'LanguageAdmired']).size().reset_index(name='Count')

    # Get the top 10 most frequent countries
    top_countries = df['Country'].value_counts(ascending=False).head(10).index

    # Filter the grouped data to include only rows for the top 10 countries
    country_tech_top = country_tech[country_tech['Country'].isin(top_countries)]
    #fds=country_tech_top[country_tech_top.value_counts(ascending=False)]
    print(country_tech_top)
    sns.scatterplot(
        data=country_tech_top, #country_tech_top[country_tech_top['Country'].isin(top_countries)],
        x='Country',
        y='Count',
        hue='LanguageAdmired', 
        size=0,
        sizes=(100, 2000)
    )
    plt.xticks(rotation=90)
    plt.legend(title='Legend Title', bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=3)
    plt.title('Admired Technologies by Country')
    plt.tight_layout()

# Execute visualization
bubble_analysis = create_comprehensive_bubble_analysis(df)
# Out:
#                        Country          LanguageAdmired  Count
# 392                     Brazil                     Apex      6
# 393                     Brazil                 Assembly      6
# 394                     Brazil  Bash/Shell (all shells)    188
# 395                     Brazil                        C     52
# 396                     Brazil                       C#    142
# ...                        ...                      ...    ...
# 3029  United States of America               TypeScript   1931
# 3030  United States of America                      VBA     65
# 3031  United States of America      Visual Basic (.Net)     71
# 3032  United States of America                   Zephyr     10
# 3033  United States of America                      Zig     48
#
# [470 rows x 3 columns]

# %% [markdown]
# ### Task 1: Exploring Data Distributions Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Age vs. Frequency of Participation

# %% [markdown]
# - Visualize the relationship between respondents’ age and their participation frequency (`SOPartFreq`) using a bubble plot.
#
# - Use the size of the bubbles to represent their job satisfaction (`JobSat`).

# %%
##Write your code here

# %% [markdown]
# #### 2. Bubble Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# -Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSat`).
#
# - Use the size of the bubbles to represent respondents’ age.

# %%
##Write your code here

# %% [markdown]
# ### Task 2: Analyzing Relationships Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot of Technology Preferences by Age
#
# - Visualize the popularity of programming languages respondents have worked with (`LanguageHaveWorkedWith`) across age groups.
#
# - Use bubble size to represent the frequency of each language.

# %%
##Write your code here

# %% [markdown]
# #### 2. Bubble Plot for Preferred Databases vs. Job Satisfaction
#
# - Explore the relationship between preferred databases (`DatabaseWantToWorkWith`) and job satisfaction.
#
# - Use bubble size to indicate the number of respondents for each database.

# %%
##Write your code here

# %% [markdown]
# ### Task 3: Comparing Data Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Compensation Across Developer Roles
#
# - Visualize compensation (`ConvertedCompYearly`) across different developer roles (`DevType`).
#
# - Use bubble size to represent job satisfaction.

# %%
##Write your code here

# %% [markdown]
# #### 2. Bubble Plot for Collaboration Tools by Age
#
# - Visualize the relationship between the collaboration tools used (`NEWCollabToolsHaveWorkedWith`) and age groups.
#
# - Use bubble size to represent the frequency of tool usage.

# %%
##Write your code here

# %% [markdown]
# ### Task 4: Visualizing Technology Trends Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Preferred Web Frameworks vs. Job Satisfaction
#
# - Explore the relationship between preferred web frameworks (`WebframeWantToWorkWith`) and job satisfaction.
#
# - Use bubble size to represent the number of respondents.

# %%
##Write your code here

# %% [markdown]
# #### 2. Bubble Plot for Admired Technologies Across Countries
#
# - Visualize the distribution of admired technologies (`LanguageAdmired`) across different countries (`Country`).
#
# - Use bubble size to represent the frequency of admiration.

# %%
##Write your code here

# %% [markdown]
# ## Final Step: Review

# %% [markdown]
# After completing the lab, you will have extensively used bubble plots to gain insights into developer community preferences, demographics, compensation trends, and job satisfaction.

# %% [markdown]
# ## Summary

# %% [markdown]
# After completing this lab, you will be able to:
#
# - Create and interpret bubble plots to analyze relationships and compositions within datasets.
#
# - Use bubble plots to explore developer preferences, compensation trends, and satisfaction levels.
#
# - Apply bubble plots to visualize complex relationships involving multiple dimensions effectively.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-29|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
